# %% [markdown]
# # Tryviana Yusriska - Big Data A
#
# # Latihan:
#
# ### One to many relationship
# 1. Report the account representative for each customer.
# 2. Report total payments for Atelier graphique.
# 3. Report the total payments by date
# 4. Report the products that have not been sold.
# 5. List the amount paid by each customer.
# 6. How many orders have been placed by Herkku Gifts?
# 7. Who are the employees in Boston?
# 8. Report those payments greater than \$100,000. Sort the report so the customer who made the highest payment appears first.
# 9. List the value of 'On Hold' orders.
# 10. Report the number of orders 'On Hold' for each customer.
#
# ### Many to many relationship
# 1. List products sold by order date.
# 2. List the order dates in descending order for orders for the 1940 Ford Pickup Truck.
# 3. List the names of customers and their corresponding order number where a particular order from that customer has a value greater than $25,000?
# 4. Are there any products that appear on all orders?
# 5. List the names of products sold at less than 80% of the MSRP.
# 6. Reports those products that have been sold with a markup of 100% or more (i.e.,  the priceEach is at least twice the buyPrice)
# 7. List the products ordered on a Monday.
# 8. What is the quantity on hand for products listed on 'On Hold' orders?

# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ========================================================================

# %% [markdown]
# ## One to many relationship

# %%
# 1 Report the account representative for each customer.
run("""
select customerNumber, customerName, salesRepEmployeeNumber, concat(firstName, ' ', lastName) as accountRepresentative
from customers C
inner join employees E on C.salesRepEmployeeNumber = E.employeeNumber""")
# Out:
#     customerNumber                        customerName  \
# 0              124        Mini Gifts Distributors Ltd.
# 1              129                     Mini Wheels Co.
# 2              161                Technics Stores Inc.
# 3              321            Corporate Gift Ideas Co.
# 4              450           The Sharp Gifts Warehouse
# 5              487            Signal Collectibles Ltd.
# 6              112                  Signal Gift Stores
# 7              205                   Toys4GrownUps.com
# 8              219                   Boards & Toys Co.
# 9              239        Collectable Mini Designs Co.
# 10             347          Men 'R' US Retailers, Ltd.
# 11             475         West Coast Collectables Co.
# 12             173          Cambridge Collectables Co.
# 13             204            Online Mini Collectables
# 14             320                 Mini Creations Ltd.
# 15             339             Classic Gift Ideas, Inc
# ...

# %%
#2.Report total payments for Atelier graphique.
#run("""select * from customers where customerName like '%Atelier%'""")

run("""
select customerNumber, customerName, sum(amount) as total
from customers
inner join payments using(customerNumber)
where customerName = 'Atelier graphique'
group by customerNumber, customerName
""")
# Out:
#    customerNumber       customerName     total
# 0             103  Atelier graphique  22314.36

# %%
#3.Report the total payments by date

run("""
select YEAR(paymentDate) as Tahun,
       MONTH(paymentDate) as Bulan,
       DAY(paymentDate) as Hari,
       sum(amount) as Total
from payments
group by tahun, bulan, hari
""")
# Out:
#      Tahun  Bulan  Hari      Total
# 0     2003      1    16   10223.83
# 1     2003      1    28   10549.01
# 2     2003      1    30    5494.78
# 3     2003      2    16   50218.95
# 4     2003      2    20   53959.21
# 5     2003      2    25   40206.20
# 6     2003      3     2   52151.81
# 7     2003      3     9   51001.22
# 8     2003      3    12   22292.62
# 9     2003      3    20   25833.14
# 10    2003      3    27   48425.69
# 11    2003      4     9   24212.79
# 12    2003      4    11   11044.30
# 13    2003      4    16   21665.98
# 14    2003      4    19    1627.56
# 15    2003      4    20   33383.14
# 16    2003      4    22   44380.15
# 17    2003      5     9    3101.40
# 18    2003      5    12   35826.33
# 19    2003      5    20   45864.03
# 20    2003      5    21   16700.47
# 21    2003      5    25   50824.66
# 22    2003      5    31    7565.08
# 23    2003      6     5   14571.44
# 24    2003      6     6   32641.98
# 25    2003      6    13   57131.92
# ...

# %%
# 4. Report the products that have not been sold.
run("""
select P.productCode, P.productName,O.productCode
from products P
left join orderdetails O using(productCode)
where O.productCode is null
""")
# Out:
#   productCode        productName productCode
# 0    S18_3233  1985 Toyota Supra        None

# %%
# 5.List the amount paid by each customer.
run("""
select customerNumber, customerName, sum(amount) as amount
from customers
left join payments using(customerNumber)
group by customerNumber,customerName
""")
# Out:
#      customerNumber                        customerName     amount
# 0               103                   Atelier graphique   22314.36
# 1               112                  Signal Gift Stores   80180.98
# 2               114          Australian Collectors, Co.  180585.07
# 3               119                   La Rochelle Gifts  116949.68
# 4               121                  Baane Mini Imports  104224.79
# 5               124        Mini Gifts Distributors Ltd.  584188.24
# 6               125                  Havel & Zbyszek Co        NaN
# 7               128                Blauer See Auto, Co.   75937.76
# 8               129                     Mini Wheels Co.   66710.56
# 9               131                   Land of Toys Inc.  107639.94
# 10              141              Euro+ Shopping Channel  715738.98
# 11              144            Volvo Model Replicas, Co   43680.65
# 12              145            Danish Wholesale Imports  107446.50
# ...

# %%
# 6. How many orders have been placed by Herkku Gifts?
run("""
select C.customerNumber, C.customerName, sum( OD.quantityOrdered) as totalOrder
from customers C
inner join orders O using(customerNumber) 
inner join orderdetails OD using(orderNumber)

where customerName like '%Herkku%'
group by C.customerNumber, C.customerName
""")
# Out:
#    customerNumber  customerName  totalOrder
# 0             167  Herkku Gifts       973.0

# %%
# 7. Who are the employees in Boston?
run("""
select city, concat(firstName, ' ', lastName) as employeeName
from offices O
inner join employees using (officeCode)
where city = 'Boston'
""")
# Out:
#      city     employeeName
# 0  Boston   Julie Firrelli
# 1  Boston  Steve Patterson

# %%
# 8. Report those payments greater than $100,000. Sort the report so the customer who made the highest payment appears first.

run("""
select customers.customerNumber, customerName, sum(amount) as totalPayments
from payments
inner join customers using (customerNumber)
group by customers.customerNumber, customerName
having totalPayments > 100000
order by totalPayments desc
""")
# Out:
#     customerNumber                  customerName  totalPayments
# 0              141        Euro+ Shopping Channel      715738.98
# 1              124  Mini Gifts Distributors Ltd.      584188.24
# 2              114    Australian Collectors, Co.      180585.07
# 3              151            Muscle Machine Inc      177913.95
# 4              148       Dragon Souveniers, Ltd.      156251.03
# 5              323    Down Under Souveniers, Inc      154622.08
# 6              187                AV Stores, Co.      148410.09
# 7              276       Anna's Decorations, Ltd      137034.22
# 8              321      Corporate Gift Ideas Co.      132340.78
# 9              146        Saveley & Henriot, Co.      130305.35
# 10             278                 Rovelli Gifts      127529.69
# 11             353            Reims Collectables      126983.19
# 12             119             La Rochelle Gifts      116949.68
# 13             363  Online Diecast Creations Co.      116449.29
# ...

# %%
#9. List the value of 'On Hold' orders.

run("""
select O.orderNumber, sum(quantityOrdered * priceEach) as value
from orders O
inner join orderdetails OD using(orderNumber)
where status ='On Hold'
group by O.orderNumber
""")
# Out:
#    orderNumber     value
# 0        10334  23014.17
# 1        10401  43525.04
# 2        10407  52229.55
# 3        10414  50806.85

# %%
# 10. Report the number of orders 'On Hold' for each customer.
run("""
select customerName, count(orderNumber) as numberOfOrder
from orders
inner join customers using (customerNumber)
where status = 'On Hold'
group by customerName
""")
# Out:
#                 customerName  numberOfOrder
# 0          Gifts4AllAges.com              1
# 1    Tekni Collectables Inc.              1
# 2  The Sharp Gifts Warehouse              1
# 3   Volvo Model Replicas, Co              1

# %% [markdown]
# ## Many to many relationship

# %%
#1. List products sold by order date  ?productCode, productName,
run("""
select orderDate , sum(quantityOrdered) totalSold
from orders O
inner join orderdetails OD using (orderNumber)
inner join products P using (productCode)
group by orderDate
""")
# Out:
#       orderDate  totalSold
# 0    2003-01-06      151.0
# 1    2003-01-09      142.0
# 2    2003-01-10       80.0
# 3    2003-01-29      541.0
# 4    2003-01-31      443.0
# 5    2003-02-11      545.0
# 6    2003-02-17      675.0
# 7    2003-02-24      229.0
# 8    2003-03-03      561.0
# 9    2003-03-10      212.0
# 10   2003-03-18      570.0
# 11   2003-03-24       52.0
# 12   2003-03-25      217.0
# 13   2003-03-26      143.0
# 14   2003-04-01      351.0
# 15   2003-04-04      210.0
# 16   2003-04-11       27.0
# 17   2003-04-16      402.0
# 18   2003-04-21       36.0
# 19   2003-04-28      442.0
# 20   2003-04-29      525.0
# 21   2003-05-07      185.0
# 22   2003-05-08      545.0
# 23   2003-05-20      156.0
# 24   2003-05-21      514.0
# 25   2003-05-28      617.0
# 26   2003-06-03      540.0
# 27   2003-06-06      157.0
# 28   2003-06-12      349.0
# 29   2003-06-16      317.0
# ..          ...        ...
# 235  2005-03-04      603.0
# 236  2005-03-09      339.0
# ...

# %%
#2. List the order dates in descending order for orders for the 1940 Ford Pickup Truck.
run("""
select orderDate
from orders 
inner join orderdetails using (orderNumber)
inner join products using (productCode)
where productName = '1940 Ford Pickup Truck'
order by orderDate desc
""")
# Out:
#      orderDate
# 0   2005-05-31
# 1   2005-05-01
# 2   2005-03-09
# 3   2005-02-17
# 4   2005-01-20
# 5   2004-12-10
# 6   2004-11-29
# 7   2004-11-18
# 8   2004-11-04
# 9   2004-10-21
# 10  2004-10-11
# 11  2004-09-08
# 12  2004-08-17
# 13  2004-07-19
# 14  2004-06-15
# 15  2004-05-04
# 16  2004-03-10
# 17  2004-01-29
# 18  2003-12-05
# 19  2003-11-25
# 20  2003-11-13
# 21  2003-11-06
# 22  2003-10-21
# 23  2003-09-19
# 24  2003-07-24
# 25  2003-05-28
# 26  2003-03-26
# 27  2003-01-29

# %%
#3. List the names of customers and their corresponding order number where a particular order from 
#that customer has a value greater than $25,000?

run("""
select customerName, O.orderNumber, sum(quantityOrdered * priceEach) amount
from customers
inner join orders O using (customerNumber)
inner join orderDetails using (orderNumber)
group by customerName, orderNumber
having amount > 25000
order by customerName
""")
# Out:
#                            customerName  orderNumber    amount
# 0                          Alpha Cognac        10178  33818.34
# 1                    Amica Models & Co.        10280  48298.99
# 2                    Amica Models & Co.        10293  33924.24
# 3               Anna's Decorations, Ltd        10148  41554.73
# 4               Anna's Decorations, Ltd        10169  38547.19
# 5               Anna's Decorations, Ltd        10370  27083.78
# 6               Anna's Decorations, Ltd        10391  29848.52
# 7          Australian Collectables, Ltd        10193  35505.63
# 8            Australian Collectors, Co.        10120  45864.03
# 9            Australian Collectors, Co.        10223  44894.74
# 10           Australian Collectors, Co.        10342  40265.60
# 11           Australian Collectors, Co.        10347  41995.62
# 12                 Auto Associés & Cie.        10304  53116.99
# 13                    Auto Canal+ Petit        10211  49165.16
# ...

# %%
# 4. Are there any products that appear on all orders?

run("""
select productCode, count(orderNumber) as appear
from orderDetails
group by productCode
having appear = (select count(1) from orders)
""")

#tidak ada
# Out:
# Empty DataFrame
# Columns: [productCode, appear]
# Index: []

# %%
#5. List the names of products sold at less than 80% of the MSRP.
run("""
select orderNumber, P.productCode, productName, MSRP,priceEach
from products P
inner join orderdetails OD using (productCode)
where priceEach < (0.8 * MSRP)

""")
# Out:
#     orderNumber productCode                                  productName  \
# 0         10354    S10_2016                        1996 Moto Guzzi 1100i
# 1         10287    S18_1129                              1993 Mazda RX-7
# 2         10356    S18_1342                         1937 Lincoln Berline
# 3         10266    S18_1589                        1965 Aston Martin DB5
# 4         10331    S18_1589                        1965 Aston Martin DB5
# 5         10143    S18_1662                  1980s Black Hawk Helicopter
# 6         10360    S18_1662                  1980s Black Hawk Helicopter
# 7         10312    S18_2248                           1911 Ford Town Car
# 8         10223    S18_2581                               P-51-D Mustang
# 9         10263    S18_2581                               P-51-D Mustang
# 10        10239    S18_3232                  1992 Ferrari 360 Spider red
# 11        10281    S18_3232                  1992 Ferrari 360 Spider red
# ...

# %%
#6. Reports those products that have been sold with a markup of 100% or more (i.e., the priceEach is at least twice the buyPrice)
#6.1 asumsi products di list sesuai ordernumbernya, dan products dg ordernumber bersesuaian dengan ratenya yang >= 2 yang dilist
run("""
select productName, orderNumber,buyPrice, priceEach, (priceEach/buyPrice) as rate
from products 
inner join orderDetails using(productCode)
having rate >= 2
""")
# Out:
#                               productName  orderNumber  buyPrice  priceEach  \
# 0                1952 Alpine Renault 1300        10103     98.58     214.30
# 1                1952 Alpine Renault 1300        10112     98.58     197.16
# 2                1952 Alpine Renault 1300        10126     98.58     205.73
# 3                1952 Alpine Renault 1300        10163     98.58     212.16
# 4                1952 Alpine Renault 1300        10174     98.58     207.87
# 5                1952 Alpine Renault 1300        10194     98.58     203.59
# 6                1952 Alpine Renault 1300        10206     98.58     203.59
# 7                1952 Alpine Renault 1300        10215     98.58     205.73
# 8                1952 Alpine Renault 1300        10228     98.58     214.30
# 9                1952 Alpine Renault 1300        10280     98.58     205.73
# 10               1952 Alpine Renault 1300        10291     98.58     210.01
# ...

# %%
#6.2 asumsi jika product pernah dijual dengan rate >= 2, product masuk list. rate = (priceEach/buyPrice) 
run("""
select productName
from products 
inner join orderDetails using(productCode)
where (priceEach/buyPrice) >= 2
group by productName


""")
# Out:
#                                   productName
# 0                       1926 Ford Fire Engine
# 1                    1928 Ford Phaeton Deluxe
# 2                      1928 Mercedes-Benz SSK
# 3         1932 Alfa Romeo 8C2300 Spider Sport
# 4                   1932 Model A Ford J-Coupe
# 5         1936 Harley Davidson El Knucklehead
# 6    1936 Mercedes-Benz 500K Special Roadster
# 7                   1937 Horch 930V Limousine
# 8   1938 Cadillac V-16 Presidential Limousine
# 9                     1939 Cadillac Limousine
# 10                     1940 Ford Pickup Truck
# 11             1948 Porsche Type 356 Roadster
# 12     1950's Chicago Surface Lines Streetcar
# 13                   1952 Alpine Renault 1300
# 14                1954 Greyhound Scenicruiser
# 15                          1957 Chevy Pickup
# 16                  1957 Corvette Convertible
# 17                      1957 Ford Thunderbird
# 18        1958 Chevy Corvette Limited Edition
# ...

# %%
#7. List the products ordered on a Monday. 
# weekday = 0 => monday
run("""
select distinct productName, weekday(orderDate) day
from orders o
inner join orderdetails od using (orderNumber)
inner join products p using (productCode)
having day = 0
""")
# Out:
#                                     productName  day
# 0         1969 Harley Davidson Ultimate Chopper    0
# 1                      1952 Alpine Renault 1300    0
# 2                         1996 Moto Guzzi 1100i    0
# 3          2003 Harley-Davidson Eagle Drag Bike    0
# 4                           1972 Alfa Romeo GTA    0
# 5                        1962 LanciaA Delta 16V    0
# 6                             1968 Ford Mustang    0
# 7                             2001 Ferrari Enzo    0
# 8                                1958 Setra Bus    0
# 9                              2002 Suzuki XREO    0
# 10                           1969 Corvair Monza    0
# 11                           1968 Dodge Charger    0
# 12                      1970 Plymouth Hemi Cuda    0
# 13                           1969 Dodge Charger    0
# 14                       1940 Ford Pickup Truck    0
# 15                              1993 Mazda RX-7    0
# 16                         1937 Lincoln Berline    0
# ...

# %%
#8. What is the quantity on hand for products listed on 'On Hold' orders?
run("""
select productName, quantityInStock
from orders o 
inner join orderdetails od using (orderNumber)
inner join products p using (productCode)
where status = 'On Hold'
""")
# Out:
#                             productName  quantityInStock
# 0                1962 LanciaA Delta 16V             6791
# 1                1964 Mercedes Tour Bus             8258
# 2                 1926 Ford Fire Engine             2018
# 3           1992 Ferrari 360 Spider red             8347
# 4                      1940s Ford truck             3128
# 5              1962 Volkswagen Microbus             2327
# 6                        P-51-D Mustang              992
# 7      1928 British Royal Navy Airplane             3627
# 8              Corsair F4U ( Bird Cage)             6812
# 9               1900s Vintage Tri-Plane             2756
# 10                     1997 BMW F650 ST              178
# 11             1928 Ford Phaeton Deluxe              136
# 12         1930 Buick Marquette Phaeton             7062
# 13          American Airlines: B767-300             5841
# 14       America West Airlines B757-200             9653
# ...

# %% [markdown]
# ============================end of code===============================
